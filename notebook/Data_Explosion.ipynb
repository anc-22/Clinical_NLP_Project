# %% [markdown]
# ### Importing Libraries

# %%
from IPython import get_ipython
from IPython.display import display
import pandas as pd
import ast
import os
import json
import csv
import re
from tqdm import tqdm

# %% [markdown]
# ### Loading Parsed Dataset

# %%
def get_data_path(filename):
    """
    Returns the path to a file in the data/clean directory.
    
    Args:
        filename (str): Name of the file (including extension)
    
    Returns:
        str: Full path to the file
    """
    cwd = os.getcwd()
    file_path = os.path.join(cwd, '..', 'data', 'clean', filename)
    return file_path

# %%
final_parsed_dataset = get_data_path('final_parsed_dataset.csv')
df = pd.read_csv(final_parsed_dataset, index_col=0)

# %%
df
# Out:
#           idx                                   visit motivation  \
# 0      155216  Discomfort in the neck and lower back, restric...
# 2      133948  Pain and restricted range of motion in the lef...
# 3       80176     Pain in the left proximal forearm after a fall
# 4       72232  Recurrent attacks of pain in both knees over 1...
# 5       31864  Inability to walk and a long history of osteom...
# ...       ...                                                ...
# 29995   39279                       Stab wound under left nipple
# 29996  137017                  Diagnosed with falcine meningioma
# 29997   98004                        Cardiac sounding chest pain
# 29998  133320                            Mass in her right thigh
# 29999   97973  Acute onset crushing substernal chest pressure...
#
#                                                admission  \
# 0      [{'reason': 'None', 'date': 'None', 'duration'...
# 2      [{'reason': 'Idiopathic osteonecrosis of the f...
# 3      [{'reason': 'None', 'date': 'None', 'duration'...
# 4      [{'reason': 'None', 'date': 'None', 'duration'...
# 5      [{'reason': 'None', 'date': 'None', 'duration'...
# ...                                                  ...
# 29995  [{'reason': '5 cm stab wound under left nipple...
# 29996  [{'reason': 'Craniotomy', 'date': 'None', 'dur...
# 29997  [{'reason': 'ST elevation myocardial infarctio...
# 29998  [{'reason': 'Diagnosis of leiomyosarcoma', 'da...
# 29999  [{'reason': 'Acute onset crushing substernal c...
#
#                                      patient information  \
# 0      {'age': 'Sixteen years old', 'sex': 'Female', ...
# 2      {'age': '36 years old', 'sex': 'Female', 'ethn...
# 3      {'age': '49', 'sex': 'male', 'ethnicity': 'Non...
# 4      {'age': '47', 'sex': 'Male', 'ethnicity': 'Non...
# 5      {'age': '24 years', 'sex': 'Female', 'ethnicit...
# ...                                                  ...
# 29995  {'age': '28', 'sex': 'male', 'ethnicity': 'Non...
# 29996  {'age': '82', 'sex': 'Male', 'ethnicity': 'Non...
# 29997  {'age': '54', 'sex': 'Male', 'ethnicity': 'Non...
# 29998  {'age': '49', 'sex': 'Woman', 'ethnicity': 'No...
# 29999  {'age': '31', 'sex': 'male', 'ethnicity': 'Non...
#
#                                  patient medical history  \
# 0      {'physiological context': 'None', 'psychologic...
# 2      {'physiological context': 'None', 'psychologic...
# 3      {'physiological context': 'History of left elb...
# 4      {'physiological context': 'None', 'psychologic...
# 5      {'physiological context': 'Inability to walk s...
# ...                                                  ...
# 29995  {'physiological context': 'None', 'psychologic...
# 29996  {'physiological context': "Atrial fibrillation...
# 29997  {'physiological context': 'No past medical his...
# 29998  {'physiological context': 'Noticed the mass fo...
# 29999  {'physiological context': 'No significant past...
#
#                                                surgeries  \
# 0      [{'reason': 'None', 'Type': 'None', 'time': 'N...
# 2      [{'reason': 'Idiopathic osteonecrosis of the f...
# 3      [{'reason': 'Posttraumatic arthritis', 'Type':...
# 4      [{'reason': 'None', 'Type': 'None', 'time': 'N...
# 5      [{'reason': 'Contracted pelvis', 'Type': 'Cesa...
# ...                                                  ...
# 29995  [{'reason': 'Stab wound under left nipple with...
# 29996  [{'reason': 'Prostate issue', 'Type': 'Prostat...
# 29997  [{'reason': 'Inferior segment elevation (ST) e...
# 29998  [{'reason': 'Leiomyosarcoma', 'Type': 'Wide tu...
# 29999  [{'reason': 'Acute severe aortic insufficiency...
#
#                                                 symptoms  \
# 0      [{'name of symptom': 'Discomfort in the neck a...
# 2      [{'name of symptom': 'Pain', 'intensity of sym...
# 3      [{'name of symptom': 'Pain', 'intensity of sym...
# 4      [{'name of symptom': 'Pain', 'intensity of sym...
# 5      [{'name of symptom': 'Inability to walk', 'int...
# ...                                                  ...
# 29995  [{'name of symptom': 'Dyspnoea', 'intensity of...
# 29996  [{'name of symptom': 'Left-sided weakness', 'i...
# 29997  [{'name of symptom': 'Chest pain', 'intensity ...
# 29998  [{'name of symptom': 'Mass in right thigh', 'i...
# 29999  [{'name of symptom': 'Crushing substernal ches...
#
#                                     medical examinations  \
# 0      [{'name': 'None', 'result': 'None', 'details':...
# 2      [{'name': 'Physical examination', 'result': 'S...
# 3      [{'name': 'Physical examination', 'result': 'N...
# 4      [{'name': 'Examination', 'result': 'Severe ten...
# 5      [{'name': 'Nerve conduction study', 'result': ...
# ...                                                  ...
# 29995  [{'name': 'Glasgow coma score', 'result': '12'...
# 29996  [{'name': 'Preoperative thoracic radiographs',...
# 29997  [{'name': 'Electrocardiogram', 'result': 'ST e...
# 29998  [{'name': 'Physical examination', 'result': 'C...
# 29999  [{'name': 'Physical exam', 'result': 'Initiall...
#
#                                          diagnosis tests  \
# 0      [{'test': 'None', 'severity': 'None', 'result'...
# 2      [{'test': 'Magnetic resonance imaging (MRI) sc...
# 3      [{'test': 'Radiographs', 'severity': 'Minimall...
# 4      [{'test': 'MRI', 'severity': 'Moderate-sized',...
# 5      [{'test': 'None', 'severity': 'None', 'result'...
# ...                                                  ...
# 29995  [{'test': 'Blood pressure measurement', 'sever...
# 29996  [{'test': 'Low-dose thoracic computed tomograp...
# 29997  [{'test': 'Coronary angiography', 'severity': ...
# 29998  [{'test': 'Needle biopsy', 'severity': 'None',...
# 29999  [{'test': 'Electrocardiogram (ECG)', 'severity...
#
#                                               treatments  \
# 0      [{'name': 'Olanzapine tablets', 'related condi...
# 2                                                    NaN
# 3      [{'name': 'Closed treatment in a cast', 'relat...
# 4      [{'name': 'Diclofenac sodium', 'related condit...
# 5      [{'name': 'Calcium and vitamin D', 'related co...
# ...                                                  ...
# 29995  [{'name': 'Intravenous fluid therapy', 'relate...
# 29996  [{'name': 'Anesthesia', 'related condition': '...
# 29997  [{'name': 'Primary coronary intervention', 're...
# 29998  [{'name': 'Systemic chemotherapy', 'related co...
# 29999  [{'name': 'Rapid sequence intubation', 'relate...
#
#                                                discharge  _raw_summary
# 0      {'reason': 'None', 'referral': 'None', 'follow...           NaN
# 2      {'reason': 'Good condition post-surgery', 'ref...           NaN
# 3      {'reason': 'None', 'referral': 'None', 'follow...           NaN
# 4      {'reason': 'None', 'referral': 'None', 'follow...           NaN
# 5      {'reason': 'None', 'referral': 'None', 'follow...           NaN
# ...                                                  ...           ...
# 29995  {'reason': 'None', 'referral': 'None', 'follow...           NaN
# 29996  {'reason': 'None', 'referral': 'None', 'follow...           NaN
# 29997  {'reason': 'None', 'referral': 'None', 'follow...           NaN
# 29998  {'reason': 'None', 'referral': 'None', 'follow...           NaN
# 29999  {'reason': 'Remarkably uncomplicated postopera...           NaN
#
# [29755 rows x 12 columns]

# %% [markdown]
# ### Exploding Patient Information & Medical History Column

# %%
def parse_patient_profile(val):
    """
    Converts each entry to a dictionary:
    - Handles NaN/missing
    - Handles single or multiple dicts in string
    - Handles already-parsed dicts
    - Merges multiple dicts into one (last key wins)
    """
    if pd.isna(val) or val is None:
        return {}, False  # Return empty dict, flag as missing
    if isinstance(val, dict):
        return val, True
    try:
        parsed = ast.literal_eval(val)
        if isinstance(parsed, dict):
            return parsed, True
        if isinstance(parsed, list):  # Handle rare case where it's a list of dicts
            result = {}
            for d in parsed:
                if isinstance(d, dict):
                    result.update(d)
            return result, True if result else False
    except Exception:
        pass
    # Handle string with multiple dicts not in a list
    dict_strs = re.findall(r"\{.*?\}", str(val))
    merged = {}
    found = False
    for d in dict_strs:
        try:
            parsed_d = ast.literal_eval(d)
            if isinstance(parsed_d, dict):
                merged.update(parsed_d)
                found = True
        except Exception:
            continue
    return merged, found

# %%
# Select and copy
df_patient_info = df[['idx','patient information']].copy()

# Parse/merge and create the flag
parsed_results = df_patient_info['patient information'].apply(parse_patient_profile)
df_patient_info['parsed_dict'] = parsed_results.apply(lambda x: x[0])

# Expand as columns
info_df = df_patient_info['parsed_dict'].apply(pd.Series)

# Join idx and expanded fields
df_info_expanded = pd.concat([df_patient_info['idx'], info_df], axis=1)

# Replace 'None' value with NA for consistency
df_info_expanded.replace('None', pd.NA, inplace=True)

# Select only age and sex for futher processing
df_info_expanded = df_info_expanded[['idx', 'age', 'sex']]
df_info_expanded.head(20)
# Out:
#        idx                      age     sex
# 0   155216        Sixteen years old  Female
# 2   133948             36 years old  Female
# 3    80176                       49    male
# 4    72232                       47    Male
# 5    31864                 24 years  Female
# 6    26809               24-day-old  Female
# 7   149866             16 years old  Female
# 8    87064  Seventy-three years old    Male
# 9   123006                       23  female
# 10  119317                       32  Female
# 11   92167                       64    Male
# 12   42234                       13  Female
# 13   92105                       60  Female
# 14   89665                       47    Male
# 15  149815                       68    male
# 16   91779             49 years old  Female
# 17  146172                       82  Female
# 18   89642                       78    male
# 19   90928             9 months old  Female
# 20   43555                       58    male

# %%
df_info_expanded.to_csv('df_info_expanded.csv')

# %%
# Select and copy
df_medical_history = df[['idx','patient medical history']].copy()

# Parse/merge and create the flag
parsed_results = df_medical_history['patient medical history'].apply(parse_patient_profile)
df_medical_history['parsed_dict'] = parsed_results.apply(lambda x: x[0])
df_medical_history['has_medical_history'] = parsed_results.apply(lambda x: x[1])

# Expand as columns
history_df = df_medical_history['parsed_dict'].apply(pd.Series)

# Join idx, flag, and expanded fields
df_medical_expanded = pd.concat([df_medical_history[['idx', 'has_medical_history']], history_df], axis=1)

# Replace 'None' value with NA for consistency
df_medical_expanded.replace('None', pd.NA, inplace=True)

# View result
df_medical_expanded.head(20)
# Out:
#        idx  has_medical_history  \
# 0   155216                 True
# 2   133948                 True
# 3    80176                 True
# 4    72232                 True
# 5    31864                 True
# 6    26809                 True
# 7   149866                 True
# 8    87064                 True
# 9   123006                 True
# 10  119317                 True
# 11   92167                 True
# 12   42234                 True
# 13   92105                 True
# 14   89665                 True
# 15  149815                 True
# 16   91779                 True
# 17  146172                 True
# 18   89642                 True
# 19   90928                 True
# 20   43555                 True
#
#                                 physiological context  \
# 0                                                <NA>
# 2                                                <NA>
# 3   History of left elbow arthrodesis performed fo...
# 4                                                <NA>
# 5   Inability to walk since babyhood, did not walk...
# 6   Normal Apgar score, no resuscitation required ...
# 7   Coxa vara deformity of bilateral hips, bilater...
# 8                                                <NA>
# 9                                                <NA>
# 10  Born at full term by spontaneous vaginal deliv...
# 11  Colorectal carcinoma treated by rectum and ile...
# 12                                            Healthy
# 13                                               <NA>
# 14                      Hypertension, Hyperlipidaemia
# 15                                               <NA>
# 16                    Nondiabetic and nonhypertensive
# 17                                  Otherwise healthy
# 18                                               <NA>
# 19                                               <NA>
# 20  Past medical history significant for RCC, init...
#
#                                 psychological context vaccination history  \
# 0   Diagnosed with bipolar affective disorder at t...                <NA>
# 2               Intensifying feelings of helplessness                <NA>
# 3                                                <NA>                <NA>
# 4                                                <NA>                <NA>
# 5                                                <NA>                <NA>
# 6                                                <NA>                <NA>
# 7                                                <NA>                <NA>
# 8   Patient could not realize that his symptoms mi...                <NA>
# 9                                                <NA>                <NA>
# 10                                   Mentally healthy                <NA>
# 11                                               <NA>                <NA>
# 12                                               <NA>                <NA>
# 13                                               <NA>                <NA>
# 14                                               <NA>                <NA>
# 15                                               <NA>                <NA>
# 16                                               <NA>                <NA>
# 17                                               <NA>                <NA>
# 18                                               <NA>                <NA>
# 19                                  Parental distress                <NA>
# 20                                               <NA>                <NA>
#
#    allergies exercise frequency nutrition  \
# 0       <NA>               <NA>      <NA>
# 2       <NA>               <NA>      <NA>
# 3       <NA>               <NA>      <NA>
# 4       <NA>               <NA>      <NA>
# 5       <NA>               <NA>      <NA>
# 6       <NA>               <NA>      <NA>
# 7       <NA>               <NA>      <NA>
# 8       <NA>               <NA>      <NA>
# 9       <NA>               <NA>      <NA>
# 10      <NA>               <NA>      <NA>
# 11      <NA>               <NA>      <NA>
# 12      <NA>               <NA>      <NA>
# 13      <NA>               <NA>      <NA>
# 14      <NA>               <NA>      <NA>
# 15      <NA>               <NA>      <NA>
# 16      <NA>               <NA>      <NA>
# 17      <NA>               <NA>      <NA>
# 18      <NA>               <NA>      <NA>
# 19      <NA>               <NA>      <NA>
# 20      <NA>               <NA>      <NA>
#
#                                        sexual history alcohol consumption  \
# 0                                                <NA>                <NA>
# 2                                                <NA>                <NA>
# 3                                                <NA>                <NA>
# 4                                                <NA>                <NA>
# 5   Got married at the age of 15 and became pregna...                <NA>
# 6                                                <NA>                <NA>
# 7                                                <NA>                <NA>
# 8                                                <NA>                <NA>
# 9                                                <NA>                <NA>
# 10                                               <NA>                <NA>
# 11                                               <NA>                <NA>
# 12                                               <NA>                <NA>
# 13                                               <NA>                <NA>
# 14                                               <NA>                <NA>
# 15                                               <NA>                <NA>
# 16                                               <NA>                <NA>
# 17                                               <NA>                <NA>
# 18                                               <NA>                <NA>
# 19                                               <NA>                <NA>
# 20                                               <NA>                <NA>
#
#    drug usage smoking status
# 0        <NA>           <NA>
# 2        <NA>           <NA>
# 3        <NA>           <NA>
# 4        <NA>           <NA>
# 5        <NA>           <NA>
# 6        <NA>           <NA>
# 7        <NA>           <NA>
# 8        <NA>           <NA>
# 9        <NA>           <NA>
# 10       <NA>           <NA>
# 11       <NA>           <NA>
# 12       <NA>           <NA>
# 13       <NA>           <NA>
# 14       <NA>           <NA>
# 15       <NA>           <NA>
# 16       <NA>           <NA>
# 17       <NA>           <NA>
# 18       <NA>           <NA>
# 19       <NA>           <NA>
# 20       <NA>           <NA>

# %%
df_medical_expanded.to_csv('df_medical_expanded.csv')

# %% [markdown]
# ### Exploding Surgeries Column

# %%
def to_list(x):
    if isinstance(x, list):
        return x
    if pd.isna(x) or x is None:
        return [None]  # Important: use [None] instead of []
    if isinstance(x, dict):
        return [x]
    try:
        import ast
        evaluated = ast.literal_eval(x)
        if isinstance(evaluated, list):
            return evaluated
        if isinstance(evaluated, dict):
            return [evaluated]
        return [None]
    except Exception:
        return [None]

# %%
df_surgery = df[['idx', 'surgeries']].copy()
df_surgery['surgeries'] = df_surgery['surgeries'].apply(to_list)
df_surgery_exploded = df_surgery.explode('surgeries').reset_index(drop=True)

# Add a has_surgery flag
df_surgery_exploded['has_surgery'] = df_surgery_exploded['surgeries'].apply(
    lambda x: isinstance(x, dict) and any(v is not pd.NA and v not in [None, '', 'None'] for v in x.values())
)

# Expand only dict surgeries, leave others as NaN (they represent “no surgery”)
# This part was already correct in handling non-dict/empty dict cases by converting them to {}
surgery_fields = df_surgery_exploded['surgeries'].apply(
    lambda x: x if (isinstance(x, dict) and any(v is not pd.NA and v not in [None, '', 'None'] for v in x.values())) else {}
).apply(pd.Series)

df_surgery_expanded = pd.concat([df_surgery_exploded[['idx', 'has_surgery']], surgery_fields], axis=1)

# Replace 'None' value with NA for consistency
df_surgery_expanded = df_surgery_expanded.fillna(pd.NA).replace(['None','NaN'], pd.NA)

df_surgery_expanded.head(50)
# Out:
#        idx  has_surgery                                             reason  \
# 0   155216        False                                               <NA>
# 1   133948         True       Idiopathic osteonecrosis of the femoral head
# 2   133948         True  Pain and limited ROM in the contralateral hip ...
# 3    80176         True                            Posttraumatic arthritis
# 4    80176         True  Hypertrophic nonunion of ulnar shaft fracture ...
# 5    72232        False                                               <NA>
# 6    31864         True                                  Contracted pelvis
# 7    26809         True  Left-sided diaphragmatic defect with herniatio...
# 8   149866         True  Correction of deformity to realign the head, n...
# 9    87064        False                                               <NA>
# 10  123006         True   esthetic problem caused by swelling on the scalp
# 11  123006         True                   increased swelling of the lesion
# 12  123006         True                 vascular malformation at the scalp
# 13  119317        False                                               <NA>
# 14   92167         True       Massive hemorrhage and unstable hemodynamics
# 15   92167         True                  Massive hemorrhage from a fistula
# 16   42234         True                          Ruptured pancreatic tumor
# 17   92105         True      Fracture of femur in the supracondylar region
# 18   92105         True  Fracture above the dynamic condylar screw at t...
# 19   92105         True  Fracture of the femur at the new peri implant ...
# 20   89665        False                                               <NA>
# 21  149815         True  Femoral neck fracture with dislocation of the ...
# 22  149815         True  Extraction of the femoral head retained in the...
# 23  149815         True           Fistula injury of the ipsilateral ureter
# 24   91779        False                                               <NA>
# 25  146172         True                                     Osteoarthrosis
# 26  146172         True   Removal of a retained epidural catheter fragment
# 27   89642         True           Ruptured right popliteal artery aneurysm
# 28   89642         True                            Left popliteal aneurysm
# 29   90928         True                 Open fracture of her left mandible
# 30   90928         True      Removal of sutures and examination of her jaw
# 31   90928         True                    Removal of her mandibular plate
# 32   43555         True  RCC with metastasis to tail of the pancreas an...
# 33   43555         True                      High suspicion for malignancy
# 34  129465         True        Treatment for invasive ductal breast cancer
# 35  129465         True  Solid hepatic lesion and calcified lesion at t...
# 36   80892        False                                               <NA>
# 37   80727         True  Pacemaker implantation and subsequent interven...
# 38   49286         True                          Traumatic lumbar fracture
# 39  159059        False                                               <NA>
# 40   18630         True                   Uncontrolled postpartum bleeding
# 41   18630         True                            Active vaginal bleeding
# 42   18630         True                        Recurrent abundant bleeding
# 43   18630         True        Abundant bleeding and impaired hemodynamics
# 44  168381         True  Garre's osteomyelitis due to periapical infect...
# 45   45433        False                                               <NA>
# 46   76225        False                                               <NA>
# 47   88707         True                          Palpable left breast mass
# 48   88707         True      Recurrent enlarging palpable left breast mass
# 49   88707         True      Recurrent enlarging palpable left breast mass
#
#                                                  Type  \
# 0                                                <NA>
# 1                        Total Hip Arthroplasty (THA)
# 2                        Total Hip Arthroplasty (THA)
# 3                              Left elbow arthrodesis
# 4   Repair of nonunion and conversion of elbow art...
# 5                                                <NA>
# 6      Cesarean section was planned but not performed
# 7             Surgical repair of diaphragmatic defect
# 8                                   Oblique osteotomy
# 9                                                <NA>
# 10                     surgery under local anesthesia
# 11              second surgery under local anesthesia
# 12        surgical treatment under general anesthesia
# 13                                               <NA>
# 14                    Nephrectomy of the right kidney
# 15  Deployment of a stent graft across the fistula...
# 16   Laparoscopic enucleation of the pancreatic tumor
# 17    Fixation with a dynamic condylar screw assembly
# 18        Revision surgery with a longer barrel plate
# 19  Reamed antegrade intramedullary nailing with e...
# 20                                               <NA>
# 21  Hip surgery with lateral approach and anterior...
# 22  Abdominal approach Gibson with retroperitoneal...
# 23                  Urological evaluation and surgery
# 24                                               <NA>
# 25                      Right total knee arthroplasty
# 26                                Laminectomy at L2-3
# 27    Operative exploration and inlay 8 mm PTFE graft
# 28                  Repair of left popliteal aneurysm
# 29  Trans-oral approach with a five hole 1.2 mm ti...
# 30                                General anaesthetic
# 31                                General anaesthetic
# 32  Left nephrectomy; total resection of pancreas ...
# 33     Preembolization followed by surgical resection
# 34  Lumpectomy of the left breast and axillary lym...
# 35  Laparotomy, open rapid biopsy, and excision of...
# 36                                               <NA>
# 37  Dual chamber pacemaker implantation, pulse gen...
# 38                            Surgery on lumbar spine
# 39                                               <NA>
# 40                                       Hysterectomy
# 41              Cuff repair through the vaginal route
# 42              Bilateral hypogastric artery ligation
# 43                                  Emergency surgery
# 44                                  Dental extraction
# 45                                               <NA>
# 46                                               <NA>
# 47                                 Left breast biopsy
# 48                          Repeat left breast biopsy
# 49                          Repeat left breast biopsy
#
#                                                  time  \
# 0                                                <NA>
# 1                                     After diagnosis
# 2                        One year after the first THA
# 3                                    At the age of 18
# 4   Three months after the fall and subsequent con...
# 5                                                <NA>
# 6                                                <NA>
# 7                                                <NA>
# 8                                                <NA>
# 9                                                <NA>
# 10                  1 year after the swelling started
# 11              Five months after the first operation
# 12                                               <NA>
# 13                                               <NA>
# 14                                               <NA>
# 15                                               <NA>
# 16                                               <NA>
# 17                                               <NA>
# 18                                               <NA>
# 19                                               <NA>
# 20                                               <NA>
# 21                           Next day after admission
# 22                   Two days after the first surgery
# 23                                               <NA>
# 24                                               <NA>
# 25                                               <NA>
# 26          Seven weeks after the catheter had broken
# 27                                               <NA>
# 28                  Six weeks after the first surgery
# 29     During the procedure after the 25th April 2006
# 30               Seven days after the first operation
# 31                Ten weeks after the first operation
# 32    Nephrectomy 11 years ago; resection 6 years ago
# 33                            Current follow up visit
# 34                                        7 years ago
# 35                                               <NA>
# 36                                               <NA>
# 37  Implantation in 1990, replacements in 1998 and...
# 38                                               2013
# 39                                               <NA>
# 40                                  Day 6 after birth
# 41                               Postoperative day 10
# 42                               Postoperative day 20
# 43                Day 3 after admission to the clinic
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47          Seven years prior to current presentation
# 48           Four years prior to current presentation
# 49             One year prior to current presentation
#
#                                               outcome  \
# 0                                                <NA>
# 1   Discharged in good condition without specific ...
# 2   Discharged in good condition without specific ...
# 3                                                <NA>
# 4                                                <NA>
# 5                                                <NA>
# 6   Delivered vaginally and developed a fracture o...
# 7   Uneventful recovery, successful reduction of h...
# 8                                                <NA>
# 9                                                <NA>
# 10                         terminated due to bleeding
# 11                                severe hemorrhaging
# 12  complete removal of the lesion along with its ...
# 13                                               <NA>
# 14  Hematuria stopped after the operation but recu...
# 15                    Complete closure of the fistula
# 16  Successful with a postoperative pancreatic fis...
# 17                    Uneventful postoperative period
# 18                                               <NA>
# 19  Patient was ambulated on the first postoperati...
# 20                                               <NA>
# 21  Femoral head replaced, fractured femoral head ...
# 22  Femoral head extracted, no visible injury to u...
# 23  Internal drainage of the ureter introduced and...
# 24                                               <NA>
# 25  Successful without any problems during the ope...
# 26                                               <NA>
# 27                              Unremarkable recovery
# 28                                               <NA>
# 29                                    Good bony union
# 30  Facial wounds were healing well and there was ...
# 31            Plate was removed with no complications
# 32                                               <NA>
# 33  Resected mass determined to be metastasis from...
# 34                                               <NA>
# 35  Rapid biopsy showed primary HCC for the hepati...
# 36                                               <NA>
# 37  Initial surgeries successful, extraction compl...
# 38                                               <NA>
# 39                                               <NA>
# 40                                      Full recovery
# 41                                      Full recovery
# 42                                               <NA>
# 43                  No active bleeding focus detected
# 44                                               <NA>
# 45                                               <NA>
# 46                                               <NA>
# 47      Dense fibrous stroma with fibrocystic changes
# 48  Hyperplastic fibrosis, consistent with fibroma...
# 49  Findings consistent with fibromatosis of the b...
#
#                                               details
# 0                                                <NA>
# 1                           First THA on the left hip
# 2                 Second THA on the contralateral hip
# 3                       Elbow was fused at 90 degrees
# 4   The stem of the ulnar component would act as a...
# 5                                                <NA>
# 6                                                <NA>
# 7   Procedure performed in left lateral decubitus ...
# 8   Performed on the right side, first oblique ost...
# 9                                                <NA>
# 10   surgery without guidance using an imaging method
# 11  physician felt it was a simple skin lesion tha...
# 12  head elevated at a 30° angle, skin flap remove...
# 13                                               <NA>
# 14    Ureteric stent was removed during the operation
# 15  Postoperative angiogram showed complete closur...
# 16  Performed using five trocars under pneumoperit...
# 17                                               <NA>
# 18                                               <NA>
# 19  Screws in the plate were removed percutaneousl...
# 20                                               <NA>
# 21  Austin Moore prosthesis implanted; femoral hea...
# 22  Femoral head placed on the iliopsoas muscle an...
# 23       Moore prosthesis extracted, hip debrided and
# 24                                               <NA>
# 25  Epidural anesthesia was used; the epidural cat...
# 26  The patient was placed in the prone position u...
# 27  Operative exploration was performed under full...
# 28                                               <NA>
# 29  Facial laceration copiously irrigated with nor...
# 30                                               <NA>
# 31                                               <NA>
# 32                                               <NA>
# 33                     A 28 x 17 x 7 cm resected mass
# 34  Radiation therapy and seven cycles of adjuvant...
# 35           Resection of hepatic segments VI and VII
# 36                                               <NA>
# 37  Original atrial and ventricular leads abandone...
# 38                Surgery was performed due to a fall
# 39                                               <NA>
# 40  Underwent due to impaired hemodynamics caused ...
# 41  Exploration and suturing of possible bleeding ...
# 42                                               <NA>
# 43                                               <NA>
# 44  Patient was transferred to the surgical clinic...
# 45                                               <NA>
# 46                                               <NA>
# 47                                               <NA>
# 48           The tumor involved the surgical margins.
# 49           The tumor involved the surgical margins.

# %%
df_surgery_expanded.to_csv('df_surgery_expanded.csv')

# %% [markdown]
# ### Exploding Diagnosis Tests Column

# %%
df_diagnosis = df[['idx', 'diagnosis tests']].copy()
df_diagnosis['diagnosis tests'] = df_diagnosis['diagnosis tests'].apply(to_list)
df_diagnosis_exploded = df_diagnosis.explode('diagnosis tests').reset_index(drop=True)

# Add a has_diagnosis flag
df_diagnosis_exploded['has_diagnosis'] = df_diagnosis_exploded['diagnosis tests'].apply(
    lambda x: isinstance(x, dict) and any(v is not pd.NA and v not in [None, '', 'None'] for v in x.values())
)

# Expand only dict surgeries, leave others as NaN (they represent “no surgery”)
diagnosis_fields = df_diagnosis_exploded['diagnosis tests'].apply(
    lambda x: x if (isinstance(x, dict) and any(v is not pd.NA and v not in [None, '', 'None'] for v in x.values())) else {}
).apply(pd.Series)

df_diagnosis_expanded = pd.concat([df_diagnosis_exploded[['idx', 'has_diagnosis']], diagnosis_fields], axis=1)

df_diagnosis_expanded = df_diagnosis_expanded.fillna(pd.NA).replace(['None','NaN'], pd.NA)

df_diagnosis_expanded
# Out:
#           idx  has_diagnosis                                   test  \
# 0      155216          False                                   <NA>
# 1      133948           True  Magnetic resonance imaging (MRI) scan
# 2      133948           True                             Repeat MRI
# 3       80176           True                            Radiographs
# 4       72232           True                                    MRI
# ...       ...            ...                                    ...
# 61350  133320           True          Histopathological examination
# 61351   97973           True                Electrocardiogram (ECG)
# 61352   97973           True           Transthoracic echocardiogram
# 61353   97973           True                         Blood cultures
# 61354   97973           True         Transesophageal echocardiogram
#
#                                                 severity  \
# 0                                                   <NA>
# 1                                                   <NA>
# 2                                                   <NA>
# 3                                    Minimally displaced
# 4                                         Moderate-sized
# ...                                                  ...
# 61350                                               <NA>
# 61351                                               <NA>
# 61352  Ejection fraction (EF) of 45% with severe aort...
# 61353                                               <NA>
# 61354                                               <NA>
#
#                                                   result  \
# 0                                                   <NA>
# 1      Increased amount of joint fluid and bone marro...
# 2      Similar findings to those noted previously in ...
# 3                          Proximal ulnar shaft fracture
# 4      Focal area of marrow edema/contusion involving...
# ...                                                  ...
# 61350  Consistent with lung metastasis of leiomyosarcoma
# 61351     Diffuse ST depressions in all precordial leads
# 61352                           Torn right coronary cusp
# 61353       Positive for S.\nlugdunensis in both bottles
# 61354  Large vegetation prolapsing into the left vent...
#
#                                                condition  \
# 0                                                   <NA>
# 1           Idiopathic osteonecrosis of the femoral head
# 2                                                   <NA>
# 3      Proximal ulnar shaft fracture, hypertrophic no...
# 4                                      Bone marrow edema
# ...                                                  ...
# 61350                  Lung metastasis of leiomyosarcoma
# 61351         Consistent with an acute coronary syndrome
# 61352                        Severe aortic insufficiency
# 61353                                               <NA>
# 61354  Acute severe aortic insufficiency from endocar...
#
#                                                     time  \
# 0                                                   <NA>
# 1                                                   <NA>
# 2      One year after the initial surgery and symptom...
# 3                                                   <NA>
# 4      September 2016, three months later, April 2017...
# ...                                                  ...
# 61350              One year and 3 months postoperatively
# 61351                                               <NA>
# 61352                                               <NA>
# 61353                                               <NA>
# 61354                                               <NA>
#
#                                                  details
# 0                                                   <NA>
# 1      Patient did not complain of any pain on the co...
# 2                                                   <NA>
# 3      Elbow arthrodesis at 90 degrees with retained ...
# 4      Involvement of medial femoral condyle in mid a...
# ...                                                  ...
# 61350                                               <NA>
# 61351                                               <NA>
# 61352    Emergent transthoracic echocardiogram performed
# 61353                                               <NA>
# 61354              Performed while patient was intubated
#
# [61355 rows x 8 columns]

# %%
df_diagnosis_expanded['time'].unique()
# Out:
# array([<NA>,
#        'One year after the initial surgery and symptoms continued for two months and increased over the following three weeks',
#        'September 2016, three months later, April 2017, four months later',
#        ...,
#        'One year after the first performance of IgG and IgA antibody testing',
#        'Two samples collected 1 h apart from two different sites under aseptic precautions',
#        'One year and 3 months postoperatively'], dtype=object)

# %%
df_diagnosis_expanded.to_csv('df_diagnosis_expanded.csv')

# %% [markdown]
# ### Exploding Symptoms Column

# %%
df_symptoms = df[['idx', 'symptoms']].copy()
df_symptoms['symptoms'] = df_symptoms['symptoms'].apply(to_list)
df_symptoms_exploded = df_symptoms.explode('symptoms').reset_index(drop=True)

# Add a has_symptom flag
df_symptoms_exploded['has_symptom'] = df_symptoms_exploded['symptoms'].apply(
    lambda x: isinstance(x, dict) and any(v is not pd.NA and v not in [None, '', 'None'] for v in x.values())
)

# Expand only dict surgeries, leave others as NaN (they represent “no surgery”)
symptoms_fields = df_symptoms_exploded['symptoms'].apply(
    lambda x: x if (isinstance(x, dict) and any(v is not pd.NA and v not in [None, '', 'None'] for v in x.values())) else {}
).apply(pd.Series)

df_symptoms_expanded = pd.concat([df_symptoms_exploded[['idx', 'has_symptom']], symptoms_fields], axis=1)

df_symptoms_expanded = df_symptoms_expanded.fillna(pd.NA).replace(['None','NaN'], pd.NA)

df_symptoms_expanded
# Out:
#           idx  has_symptom                                    name of symptom  \
# 0      155216         True  Discomfort in the neck and lower back, restric...
# 1      133948         True                                               Pain
# 2      133948         True                         Restricted range of motion
# 3      133948         True                                   Gait disturbance
# 4      133948         True                                 Moderate moon face
# ...       ...          ...                                                ...
# 54939  137017         True                                Left-sided weakness
# 54940   98004         True                                         Chest pain
# 54941  133320         True                                Mass in right thigh
# 54942   97973         True                 Crushing substernal chest pressure
# 54943   97973         True                                            Dyspnea
#
#       intensity of symptom                         location  \
# 0                     <NA>              Neck and lower back
# 1                   Severe                   Left hip joint
# 2                     <NA>                   Left hip joint
# 3                   Severe                             <NA>
# 4                 Moderate                             Face
# ...                    ...                              ...
# 54939                 <NA>                        Left side
# 54940                 <NA>                            Chest
# 54941                 <NA>  Lateral side of the right thigh
# 54942          Acute onset                       Substernal
# 54943    Rapidly developed                             <NA>
#
#                                            time  \
# 0                              Past four months
# 1                     Persisting for two months
# 2                     Persisting for two months
# 3                                          <NA>
# 4             At the time of the second surgery
# ...                                         ...
# 54939                                      <NA>
# 54940                                      <NA>
# 54941  Noticed four years prior to presentation
# 54942                                      <NA>
# 54943                                      <NA>
#
#                                 temporalisation  \
# 0                                          <NA>
# 1      Increased over the following three weeks
# 2                                          <NA>
# 3                                          <NA>
# 4                                          <NA>
# ...                                         ...
# 54939                                      <NA>
# 54940                                      <NA>
# 54941                                      <NA>
# 54942     Following 1-week-long febrile illness
# 54943                                      <NA>
#
#                   behaviours affecting the symptom  \
# 0              Standing up from a sitting position
# 1      Aggravated by hip joint flexion or rotation
# 2                                             <NA>
# 3                            Secondary to hip pain
# 4                                             <NA>
# ...                                            ...
# 54939                                         <NA>
# 54940                                         <NA>
# 54941                                         <NA>
# 54942                                         <NA>
# 54943                                         <NA>
#
#                                                  details
# 0      Head turned to the right and upwards due to su...
# 1      Also complained of pain and limited ROM in the...
# 2                                                   <NA>
# 3      Continued for two months and increased over th...
# 4                    Initially overlooked as weight gain
# ...                                                  ...
# 54939                                               <NA>
# 54940                                   Cardiac sounding
# 54941  Diameter of 4 cm, no adhesion with skin and no...
# 54942        Accompanied by dyspnea and profuse sweating
# 54943  Patient developed dyspnea, tachypnea, and tach...
#
# [54944 rows x 9 columns]

# %%
df_symptoms_expanded.to_csv('df_symptoms_expanded.csv')

# %%
df_symptoms_expanded['time'].unique()
# Out:
# array(['Past four months', 'Persisting for two months', <NA>, ...,
#        'Presented for two days prior to admission',
#        'After playing the drums and during activities of daily life, such as when opening a bottle lid',
#        'From the last one month'], dtype=object)

# %%
df_symptoms_expanded['temporalisation'].unique()
# Out:
# array([<NA>, 'Increased over the following three weeks',
#        'Recurrent attacks', ...,
#        'Started at nine years of age and gradually increased',
#        'Accelerating over the past 2 years',
#        'Following 1-week-long febrile illness'], dtype=object)

# %% [markdown]
# ### Exploding Treatment Column

# %%
df_treatments = df[['idx', 'treatments']].copy()
df_treatments['treatments'] = df_treatments['treatments'].apply(to_list)
df_treatments_exploded = df_treatments.explode('treatments').reset_index(drop=True)

# Add a has_treatments flag
df_treatments_exploded['has_treatments'] = df_treatments_exploded['treatments'].apply(
    lambda x: isinstance(x, dict) and any(v is not pd.NA and v not in [None, '', 'None'] for v in x.values())
)

# Expand only dict treatments, leave others as NaN (they represent “no treatment”)
treatments_fields = df_treatments_exploded['treatments'].apply(
    lambda x: x if (isinstance(x, dict) and any(v is not pd.NA and v not in [None, '', 'None'] for v in x.values())) else {}
).apply(pd.Series)

df_treatments_expanded = pd.concat([df_treatments_exploded[['idx', 'has_treatments']], treatments_fields], axis=1)

df_treatments_expanded = df_treatments_expanded.fillna(pd.NA).replace(['None','NaN'], pd.NA)

df_treatments_expanded.head(20)
# Out:
#        idx  has_treatments                                   name  \
# 0   155216            True                     Olanzapine tablets
# 1   155216            True                        Trihexyphenidyl
# 2   133948           False                                   <NA>
# 3    80176            True             Closed treatment in a cast
# 4    80176            True                 Conservative treatment
# 5    72232            True                      Diclofenac sodium
# 6    72232            True               NSAIDs and physiotherapy
# 7    72232            True                 Conservative treatment
# 8    31864            True                  Calcium and vitamin D
# 9    31864            True                             Calcitriol
# 10   26809            True                        Surgical repair
# 11  149866            True       Surgical correction of deformity
# 12   87064           False                                   <NA>
# 13  123006            True                     surgical treatment
# 14  119317           False                                   <NA>
# 15   92167            True                      Blood transfusion
# 16   42234            True                   Conservative therapy
# 17   92105            True               Supervised physiotherapy
# 18   92105            True  Range of motion exercises of the knee
# 19   92105            True            Compression of the fracture
#
#                                     related condition  \
# 0                          Bipolar affective disorder
# 1                             Rigidity in upper limbs
# 2                                                <NA>
# 3                       Proximal ulnar shaft fracture
# 4                                       Ulna nonunion
# 5                                   Bone marrow edema
# 6                                   Bone marrow edema
# 7                                   Bone marrow edema
# 8                                        Osteomalacia
# 9                                        Osteomalacia
# 10                               Diaphragmatic defect
# 11  Coxa vara deformity, non-union of pathological...
# 12                                               <NA>
# 13                 vascular malformation at the scalp
# 14                                               <NA>
# 15  Hemodynamic instability due to massive hemorrhage
# 16  Hemoperitoneum caused by rupture of pancreatic...
# 17              Postoperative care for femur fracture
# 18  Postoperative care after reamed antegrade intr...
# 19  Postoperative care after reamed antegrade intr...
#
#                                 dosage                                time  \
# 0                         5 mg per day                    Past four months
# 1                         4 mg per day  Brief period of around three weeks
# 2                                 <NA>                                <NA>
# 3                                 <NA>            Initially after the fall
# 4                                 <NA>         Three months after the fall
# 5                                50 mg                      September 2016
# 6                                 <NA>   Three months after September 2016
# 7                                 <NA>                          April 2017
# 8                                 <NA>                                <NA>
# 9                        0.25 mg daily                                <NA>
# 10                                <NA>                                <NA>
# 11                                <NA>                                <NA>
# 12                                <NA>                                <NA>
# 13                                <NA>                                <NA>
# 14                                <NA>                                <NA>
# 15                             6 Units                                <NA>
# 16                                <NA>                    Prior to surgery
# 17                                <NA>               After initial surgery
# 18                                <NA>              After the last surgery
# 19  1 mm per day in divided increments              After the last surgery
#
#       frequency                    duration  \
# 0         Daily                        <NA>
# 1         Daily                        <NA>
# 2          <NA>                        <NA>
# 3          <NA>                        <NA>
# 4          <NA>  An additional three months
# 5   Twice daily                        <NA>
# 6          <NA>                        <NA>
# 7          <NA>                        <NA>
# 8          <NA>                        <NA>
# 9   Small doses       Short periods of time
# 10         <NA>                        <NA>
# 11         <NA>                        <NA>
# 12         <NA>                        <NA>
# 13         <NA>                        <NA>
# 14         <NA>                        <NA>
# 15         <NA>                        <NA>
# 16         <NA>                        <NA>
# 17         <NA>                        <NA>
# 18         <NA>                        <NA>
# 19        Daily                        <NA>
#
#                                     reason for taking  \
# 0               Control of exacerbated mental illness
# 1                             Rigidity in upper limbs
# 2                                                <NA>
# 3                   To treat the ulnar shaft fracture
# 4                          To treat the ulna nonunion
# 5                                  To treat knee pain
# 6   Treatment for new onset of pain involving the ...
# 7   Treatment for gradual pain over the medial sid...
# 8                               To treat osteomalacia
# 9                               To treat osteomalacia
# 10  To repair the diaphragmatic defect and reduce ...
# 11  To realign the head, neck, and shaft of the fe...
# 12                                               <NA>
# 13     to remove the vascular lesion and malformation
# 14                                               <NA>
# 15                          To stabilize hemodynamics
# 16                                   To stop bleeding
# 17                    To aid in recovery post-surgery
# 18                    To aid in recovery post-surgery
# 19                         To aid in fracture healing
#
#                                 reaction to treatment  \
# 0   Pain and discomfort in neck, sustained and abn...
# 1                                       Good response
# 2                                                <NA>
# 3                   Developed a hypertrophic nonunion
# 4          Worsening motion through the nonunion site
# 5                          Pain subsided and resolved
# 6                                                <NA>
# 7                                                <NA>
# 8                                      No improvement
# 9   No improvement, eventually stopped all treatments
# 10            Uneventful recovery, successful outcome
# 11                                               <NA>
# 12                                               <NA>
# 13                                               <NA>
# 14                                               <NA>
# 15                    Rapid and unremarkable recovery
# 16                                   Bleeding stopped
# 17                                               <NA>
# 18                                               <NA>
# 19                                               <NA>
#
#                                               details
# 0   Previously managed with olanzapine tablets in ...
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4                                                <NA>
# 5   Advised to avoid prolonged weight-bearing acti...
# 6   Advised to use cane to minimize weight bearing...
# 7                                                <NA>
# 8                            Became totally bedridden
# 9                                                <NA>
# 10  Primary repair using interrupted nonabsorbable...
# 11                     One stage, each side at a time
# 12                                               <NA>
# 13  performed under general anesthesia, head eleva...
# 14                                               <NA>
# 15                                               <NA>
# 16                                               <NA>
# 17  Patient was discharged with advice to undergo ...
# 18  Patient was advised to perform after being dis...
# 19  Patient was advised to compress the fracture a...
